# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from ocrmac import ocrmac

# %%
annotations = ocrmac.OCR('test.png',recognition_level='accurate').recognize(px=True)

print(annotations)
# Out:
# [('< →', 0.5, (67.93851657956601, 90.00000012499994, 115.89511694122967, 108.000000125)), ("GitHub: Let's build from here • X", 1.0, (185.831828824254, 57.99999990000005, 379.65642195264456, 69.99999990000002)), ('github.com', 0.5, (197.74611530396098, 91.58108980563327, 273.82712028312733, 106.41890985873381)), ("Let's build from here", 1.0, (151.86256584038583, 197.99999972, 991.1030721694998, 281.99999972)), ('Harnessed for productivity. Designed for collaboration.', 1.0, (149.86436879683555, 320.00000006, 883.2007159939424, 350.00000006000005)), ('Celebrated for built-in security. Welcome to the', 1.0, (151.86257175836343, 359.9999999125, 783.2911431869348, 389.9999999125001)), ('platform developers love.', 1.0, (149.86437897762204, 400.0, 491.5551565544756, 428.0)), ('Email address', 1.0, (161.85352455545515, 492.0000001, 261.76310864225445, 506.0000001)), ('Sign up for GitHub', 1.0, (363.67088437748646, 492.00000007500006, 499.5479187355335, 510.000000075)), ('Start a free enterprise trial >', 1.0, (569.4846298942134, 492.00000016, 773.3001814312839, 508.00000016)), ("Trusted by the world's leading organizations y", 1.0, (149.86437928734173, 639.9999999, 465.5786650016274, 653.9999999)), ('stripe Pinterest', 1.0, (147.86618311633512, 683.9999997333333, 383.65280156118143, 715.9999997333333)), ('KPMG', 0.30000001192092896, (405.6329105598252, 686.0000001833333, 505.5424946466245, 724.0000001833333)), ('Mercedes-Benz', 1.0, (581.4737804641952, 693.99999994, 689.3761312779384, 707.99999994)), ('PEG A TELUS', 0.5, (717.3508149721066, 685.99999987, 963.1283918256328, 719.99999987))]

# %%
img = ocrmac.OCR('test.png',language_preference=['en-US']).annotate_PIL()

img
# Out:
# <PIL.Image.Image image mode=RGBA size=1105x858>

# %%
# %%timeit
annotations =ocrmac.OCR('test.png',recognition_level='fast').recognize()
# Out:
# 213 ms ± 1.19 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
annotations =ocrmac.OCR('test.png', recognition_level='fast').recognize()
# Out:
# 214 ms ± 1.04 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
