# %%
# %load_ext autoreload
# %autoreload 2

# %%
from ocrmac import ocrmac

# %%
annotations =ocrmac.OCR('test.png',recognition_level='accurate').recognize()

print(annotations)
# Out:
# [("GitHub: Let's build from here - X", 0.5, [0.16749160105199276, 0.9183918178040816, 0.17617717015211679, 0.017733193889825416]), ('github.com', 0.5, [0.17936670897998794, 0.8767293912393075, 0.0682822584784577, 0.01655266903064878]), ('Qi &0 O M #O', 0.30000001192092896, [0.6500449236298292, 0.8744212963037776, 0.23719676540880497, 0.02083333332585202]), ("Let's build from here", 1.0, [0.13611859838274934, 0.6730324074268803, 0.7601078165316829, 0.08333333331386039]), ('Harnessed for productivity. Designed for collaboration.', 1.0, [0.13252470799640612, 0.593171296302355, 0.6657681939500683, 0.03472222221616361]), ('Celebrated for built-in security. Welcome to the', 1.0, [0.1334231805929919, 0.545717592598528, 0.5723270439274772, 0.035879629623694176]), ('platform developers love.', 1.0, [0.13252470799640612, 0.5005787037138136, 0.30817610053637734, 0.0347222222121123]), ('Email address', 1.0, [0.14600179694519316, 0.4114583333719136, 0.09344114982458393, 0.0173611110725308]), ('Si
# ...

# %%
["GitHub: Let's build from here",
 "github.com",
 "Let's build from here",
 'Harnessed for productivity. Designed for collaboration.',
 'Celebrated for built-in security. Welcome to the',
 'platform developers love.',
 'Email address',
 'Sign up for GitHub',
 'Start a free enterprise trial',
 "Trusted by the world's leading organizations",
 'Mercedes-Benz',

# %%
[_[0] for _ in annotations]
# Out:
# ["GitHub: Let's build from here - X",
#  'github.com',
#  'Qi &0 O M #O',
#  "Let's build from here",
#  'Harnessed for productivity. Designed for collaboration.',
#  'Celebrated for built-in security. Welcome to the',
#  'platform developers love.',
#  'Email address',
#  'Sign up for GitHub',
#  'Start a free enterprise trial',
#  "Trusted by the world's leading organizations y",
#  'stripe Pinterest KPMG',
#  'Mercedes-Benz',
#  'P&G U TELUS']

# %%
img =ocrmac.OCR('test.png',recognition_level='accurate').annotate_PIL()

img
# Out:
# <PIL.Image.Image image mode=RGBA size=1105x858 at 0x10FD73B80>

# %%
# %%timeit
annotations =ocrmac.OCR('test.png',recognition_level='fast').recognize()
# Out:
# 199 ms ± 3.54 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
