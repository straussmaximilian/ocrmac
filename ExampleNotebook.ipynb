# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from ocrmac import ocrmac

# %%
annotations = ocrmac.OCR('test.png',recognition_level='accurate').recognize(px=True)

print(annotations)
# Out:
# [("GitHub: Let's build from here •", 1.0, (185.83182600180834, 58.00000020000002, 357.6763106311031, 70.00000019999999)), ('github.com', 1.0, (197.77814122534426, 91.76338082528713, 273.79509436772764, 106.23661881662012)), ('M', 1.0, (981.1121154925859, 88.00000009999997, 1005.0904156734177, 110.00000009999998)), ("Let's build from here", 1.0, (151.8625655524412, 197.9999996692307, 991.1030718815551, 283.99999966923076)), ('Harnessed for productivity. Designed for collaboration.', 1.0, (151.86257390641936, 320.0000000166668, 883.2007294217901, 350.0000000166667)), ('Celebrated for built-in security. Welcome to the', 1.0, (149.8643697959314, 360.00000006, 783.2911329062388, 390.00000006000005)), ('platform developers love.', 1.0, (149.86437418196206, 397.9999997500001, 491.55515175881567, 427.99999975000003)), ('Email address', 1.0, (163.85171888146473, 491.99999990000003, 261.76311128652804, 505.99999990000003)), ('Sign up for GitHub', 1.0, (363.6708872082579, 491.9999998833334, 499
# ...

# %%
img = ocrmac.OCR('test.png',language_preference=['en-US']).annotate_PIL()

img
# Out:
# <PIL.Image.Image image mode=RGBA size=1105x858>

# %%
import platform
import subprocess

def get_m_processor_info():
    # Use subprocess to run the `sysctl` command, which retrieves system information on macOS
    try:
        processor_info = subprocess.check_output(["sysctl", "machdep.cpu.brand_string"]).strip().decode()
        return processor_info
    except subprocess.CalledProcessError:
        return "Unable to determine processor information."

# Display the processor info
processor_info = get_m_processor_info()
print(f"Processor: {processor_info}")

# Print python information
python_version = platform.python_version()

print(f"Python Version : {platform.python_version()}")
# Out:
# Processor: machdep.cpu.brand_string: Apple M3 Max
# Python Version : 3.12.12

# %%
# %%timeit
annotations = ocrmac.OCR('test.png', recognition_level='fast').recognize()
# Out:
# 74.9 ms ± 978 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
annotations = ocrmac.OCR('test.png', recognition_level='accurate').recognize()
# Out:
# 196 ms ± 5.82 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
annotations = ocrmac.OCR('test.png', framework='livetext').recognize()
# Out:
# 170 ms ± 8.81 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
